# %% [markdown]
# # DOM Inspector + Scraping Fallback (Requests → Playwright)
#
# Este notebook sirve para:
#
# - Pegar una **URL** y ver el **HTML/DOM** que recibes (lo que realmente puedes scrapear).
# - Detectar si el sitio es **dinámico (JS)** y necesitas un fallback.
# - Probar un **fallback con Playwright** (renderizado) y comparar.
#
# > Úsalo con responsabilidad: respeta `robots.txt`, términos de uso, y limita el tráfico.

# %%
# ✅ Setup (instalaciones opcionales)
# Si no tienes las librerías, descomenta y ejecuta:
# !pip -q install requests beautifulsoup4 lxml pandas tldextract

import re
import json
import time
import textwrap
from urllib.parse import urlparse, urljoin

import requests
from bs4 import BeautifulSoup
import pandas as pd

requests_session = requests.Session()
requests_session.headers.update({
    # User-Agent "realista" (ajusta si quieres)
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
})

# %%
# 🔧 Inputs
URL = "https://nexoinmobiliario.pe/inmobiliarias/edifica"
#URL = "https://example.com"   # <-- pega aquí tu URL
TIMEOUT = 25
SLEEP_BETWEEN = 1.0  # respeta el servidor
MAX_HTML_CHARS_PREVIEW = 40_000

# %%
# 🤖 robots.txt (rápido chequeo informativo)
def get_robots_txt(url: str) -> str:
    parsed = urlparse(url)
    robots_url = f"{parsed.scheme}://{parsed.netloc}/robots.txt"
    try:
        r = requests_session.get(robots_url, timeout=TIMEOUT)
        return f"robots.txt URL: {robots_url}\nStatus: {r.status_code}\n\n{r.text[:4000]}"
    except Exception as e:
        return f"No se pudo obtener robots.txt: {e}"

print(get_robots_txt(URL))
# Out:
# robots.txt URL: https://nexoinmobiliario.pe/robots.txt
# Status: 200
#
# User-Agent: *
# Disallow:
#
# Sitemap: https://nexoinmobiliario.pe/sitemap.xml

# %%
# 🌐 Fetch HTML con Requests
time.sleep(SLEEP_BETWEEN)

def fetch_html(url: str):
    r = requests_session.get(url, timeout=TIMEOUT, allow_redirects=True)
    return {
        "final_url": r.url,
        "status_code": r.status_code,
        "content_type": r.headers.get("Content-Type", ""),
        "headers": dict(r.headers),
        "text": r.text,
        "bytes": len(r.content),
    }

resp = fetch_html(URL)
print("Final URL:", resp["final_url"])
print("Status:", resp["status_code"])
print("Content-Type:", resp["content_type"])
print("Bytes:", resp["bytes"])
# Out:
# Final URL: https://nexoinmobiliario.pe/inmobiliarias/edifica
# Status: 200
# Content-Type: text/html; charset=UTF-8
# Bytes: 118464

# %%
# 🧩 DOM preview (lo que realmente te llega)
html = resp["text"]

print("HTML length:", len(html))
print("\n--- HEAD (preview) ---\n")
print(html[:MAX_HTML_CHARS_PREVIEW])
# Out:
# HTML length: 118362
#
# --- HEAD (preview) ---
#
# <!doctype html>
# <html class="no-js" lang="es">
# <head>
#     <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-PF3NRKW');</script>
# <!-- End Google Tag Manager -->
#
# <!-- Google Tag Manager -->
# <!-- <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-NT3THRFP');</script> -->
# <!-- End Google Tag Manager -->
#
#
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge"><script type="text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam.nr-data.net"]},feature_flags:["soft_nav"]};(window.NREUM||(NREUM={})).loader_config={licenseKey:"b4f15c171c",applicationID:"41434427",browserID:"41434487"};;/*! For license information please see nr-loader-rum-1.308.0.min.js.LICENSE.txt */
# (()=>{var e,t,r={163:(e,t,r)=>{"use strict";r.d(t,{j:()=>E});var n=r(384),i=r(1741);var a=r(2555);r(860).K7.genericEvents;const s="experimental.resources",o="register",c=e=>{if(!e||"string"!=typeof e)return!1;try{document.createDocumentFragment().querySelector(e)}catch{return!1}return!0};var d=r(2614),u=r(944),l=r(8122);const f="[data-nr-mask]",g=e=>(0,l.a)(e,(()=>{const e={feature_flags:[],experimental:{allow_registered_children:!1,resources:!1},mask_selector:"*",block_selector:"[data-nr-block]",mask_input_options:{color:!1,date:!1,"datetime-local":!1,email:!1,month:!1,number:!1,range:!1,search:!1,tel:!1,text:!1,time:!1,url:!1,week:!1,textarea:!1,select:!1,password:!0}};return{ajax:{deny_list:void 0,block_internal:!0,enabled:!0,autoStart:!0},api:{get allow_registered_children(){return e.feature_flags.includes(o)||e.experimental.allow_registered_children},set allow_registered_children(t){e.experimental.allow_registered_children=t},duplicate_registered_data:!1},browser_consent_mode:{enabled:!1},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},get feature_flags(){return e.feature_flags},set feature_flags(t){e.feature_flags=t},generic_events:{enabled:!0,autoStart:!0},harvest:{interval:30},jserrors:{enabled:!0,autoStart:!0},logging:{enabled:!0,autoStart:!0},metrics:{enabled:!0,autoStart:!0},obfuscate:void 0,page_action:{enabled:!0},page_view_event:{enabled:!0,autoStart:!0},page_view_timing:{enabled:!0,autoStart:!0},performance:{capture_marks:!1,capture_measures:!1,capture_detail:!0,resources:{get enabled(){return e.feature_flags.includes(s)||e.experimental.resources},set enabled(t){e.experimental.resources=t},asset_types:[],first_party_domains:[],ignore_newrelic:!0}},privacy:{cookies_enabled:!0},proxy:{assets:void 0,beacon:void 0},session:{expiresMs:d.wk,inactiveMs:d.BB},session_replay:{autoStart:!0,enabled:!1,preload:!1,sampling_rate:10,error_sampling_rate:100,collect_fonts:!1,inline_images:!1,fix_stylesheets:!0,mask_all_inputs:!0,get mask_text_selector(){return e.mask_selector},set mask_text_selector(t){c(t)?e.mask_selector="".concat(t,",").concat(f):""===t||null===t?e.mask_selector=f:(0,u.R)(5,t)},get block_class(){return"nr-block"},get ignore_class(){return"nr-ignore"},get mask_text_class(){return"nr-mask"},get block_selector(){return e.block_selector},set block_selector(t){c(t)?e.block_selector+=",".concat(t):""!==t&&(0,u.R)(6,t)},get mask_input_options(){return e.mask_input_options},set mask_input_options(t){t&&"object"==typeof t?e.mask_input_options={...t,password:!0}:(0,u.R)(7,t)}},session_trace:{enabled:!0,autoStart:!0},soft_navigations:{enabled:!0,autoStart:!0},spa:{enabled:!0,autoStart:!0},ssl:void 0,user_actions:{enabled:!0,elementAttributes:["id","className","tagName","type"]}}})());var p=r(6154),m=r(9324);let h=0;const v={buildEnv:m.F3,distMethod:m.Xs,version:m.xv,originTime:p.WN},b={consented:!1},y={appMetadata:{},get consented(){return this.session?.state?.consent||b.consented},set consented(e){b.consented=e},customTransaction:void 0,denyList:void 0,disabled:!1,harvester:void 0,isolatedBacklog:!1,isRecording:!1,loaderType:void 0,maxBytes:3e4,obfuscator:void 0,onerror:void 0,ptid:void 0,releaseIds:{},session:void 0,timeKeeper:void 0,registeredEntities:[],jsAttributesMetadata:{bytes:0},get harvestCount(){return++h}},_=e=>{const t=(0,l.a)(e,y),r=Object.keys(v).reduce((e,t)=>(e[t]={value:v[t],writable:!1,configurable:!0,enumerable:!0},e),{});return Object.defineProperties(t,r)};var w=r(5701);const x=e=>{const t=e.startsWith("http");e+="/",r.p=t?e:"https://"+e};var R=r(7836),k=r(3241);const A={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},S=e=>(0,l.a)(e,A),T=new Set;function E(e,t={},r,s){let{init:o,info:c,loader_config:d,runtime:u={},exposed:l=!0}=t;if(!c){const e=(0,n.pV)();o=e.init,c=e.info,d=e.loader_config}e.init=g(o||{}),e.loader_config=S(d||{}),c.jsAt ...
#     <link rel="alternate" hreflang="es" href="https://nexoinmobiliario.pe/inmobiliarias/edifica">
#     <!--<meta http-equiv="Content-Security-Policy" content="upgrade-insecure-requests">-->
#     <meta name="google-site-verification" content="wj-uiKFvQxnVLyg62cEPA45WY8n2aR12sX6JlraaOZ4" />
#     <title>Edifica | 15 Proyectos en Venta en Nexo Inmobiliario</title>
#     <meta name="description" content="Conoce los proyectos de Edifica. Precios desde S/. 419,136, con más de 15 en venta." />
#             <link rel="shortcut icon" href="https://nexoinmobiliario.pe/static/website/build/images/favicon.ico?v=202601120935" >
#     <meta property="og:title" content="Edifica | 15 Proyectos en Venta en Nexo Inmobiliario" />
#     <meta property="og:type" content="website" />
#     <meta property="og:url" content="https://nexoinmobiliario.pe/" />
#     <meta property="og:image" content="https://nexoinmobiliario.pe/static/website/build/images/ognexo.png?v=202601120935" />
#
#     <meta property="og:description" content="Conoce los proyectos de Edifica. Precios desde S/. 419,136, con más de 15 en venta." />
#
#     <!--<meta name="viewport" content="width=device-width, initial-scale=1">-->
#     <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=0"/>
#
#             <link rel="stylesheet" href="https://unpkg.com/leaflet@1.7.1/dist/leaflet.css" />
#         <!-- Place favicon.ico in the root directory -->
#     <link rel="stylesheet" href="https://nexoinmobiliario.pe/static/website/build/css/nexocommon.min.css?v=202601120935">
#     <script async src="https://nexoinmobiliario.pe/static/website/js/modernizr-2.8.3.min.js?v=202601120935"></script>
#     <script async src="https://nexoinmobiliario.pe/static/website/js/moment.js?v=202601120935"></script>
#
#     <script>
#       var site = 'https://nexoinmobiliario.pe/';
#       var site_image = 'https://e.nexoinmobiliario.pe/customers/';
#       var site_image_huacas = 'https://dp34qvsykz8fe.cloudfront.net/huacas/';
#       var url_static = 'https://nexoinmobiliario.pe/static/';
#       var pathname = window.location.pathname;
#
#       if(pathname.indexOf("/busqueda/") < 0 && pathname.indexOf("/departamentos/") < 0){
#         localStorage.removeItem('filter_desktop');
#       }
#       if(pathname.indexOf("/sello-codip/")<0){
#         localStorage.removeItem('filter_desktop_sello');
#       }
#       if(pathname.indexOf("/bancos/")<0){
#         localStorage.removeItem('filter_bank_bbva');
#         localStorage.removeItem('filter_bank_bcp');
#         localStorage.removeItem('filter_bank_scotiabank');
#         localStorage.removeItem('filter_bank_interbank');
#         localStorage.removeItem('filter_bank_gnb');
#         localStorage.removeItem('filter_bank_pichincha');
#         localStorage.removeItem('filter_bank_banbif');
#       }
#       var ver_modal_ferianexo = 0;
#     </script>
#                 <link rel="canonical" href="https://nexoinmobiliario.pe/inmobiliarias/edifica">
#         </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <!-- <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-PF3NRKW"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript> -->
# <!-- End Google Tag Manager (noscript) -->
#
# <!-- Google Tag Manager (noscript) -->
# <!-- <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-NT3THRFP"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript> -->
# <!-- End Google Tag Manager (noscript) -->
#
# <script>var init = [];</script>
#       <header class="headerNexo headerNexo--border headerNexo--master_temp">
#         <nav class="headerNexoNav">
#                         <div class="headerNexoNav__logo">
#                 <a href="https://nexoinmobiliario.pe/" class="">
#                    <img class="" src="https://nexoinmobiliario.pe/static/website/build/images/logo_nexo_actual.png" alt="logo Nexo Inmobiliario">
#                 </a>
#                 <button type="button" class="headerNexoNav__bars navbar-toggle">
#                     <span class="sr-only">Toggle navigation</span>
#                     <i class="fas fa-bars"></i>
#                 </button>
#                 <!-- <button type="button" class="btnUser" data-session="noSession">
#                     <i class="fas fa-user-circle"></i>
#                 </button> -->
#                 <div class="bannerCoverFormSearch__containermenus">
#                                     </div>
#             </div>
#             <nav class="headerNexoNav__nav ">
#                               <ul style="margin-left: -185px;">
#                     <li class=" header-menu-item"><a href="https://nexoinmobiliario.pe/">Home</a></li>
#                     <li class="header-menu-item "><a href="https://nexoinmobiliario.pe/sello-codip" class="">Sello CODIP</a></li>
#                     <li class="header-menu-item "><a href="https://nexoinmobiliario.pe/inmobiliarias" class="">Inmobiliarias</a></li>
#                     <li class="header-menu-item "><a href="https://nexoinmobiliario.pe/bancos" class="">Nexo-Bancos</a></li>
#                     <li class="header-menu-item "><a href="https://blog.nexoinmobiliario.pe" target="_blank">Blog</a></li>
#                 </ul>
#                           </nav>
#
#             <!-- NUEVOS BOTONES -->
#
#             <div class="headerNexoNav__buttons">
#                 <a href="#" id="btn-alertas" class="botonCampanaNotificaciones headerNexoNav__btn-alertas">
#                     <svg xmlns="http://www.w3.org/2000/svg" width="20" height="20" fill="currentColor" class="bi bi-bell" viewBox="0 0 16 16">
#                         <path d="M8 16a2 2 0 0 0 2-2H6a2 2 0 0 0 2 2M8 1.918l-.797.161A4 4 0 0 0 4 6c0 .628-.134 2.197-.459 3.742-.16.767-.376 1.566-.663 2.258h10.244c-.287-.692-.502-1.49-.663-2.258C12.134 8.197 12 6.628 12 6a4 4 0 0 0-3.203-3.92zM14.22 12c.223.447.481.801.78 1H1c.299-.199.557-.553.78-1C2.68 10.2 3 6.88 3 6c0-2.42 1.72-4.44 4.005-4.901a1 1 0 1 1 1.99 0A5 5 0 0 1 13 6c0 .88.32 4.2 1.22 6"/>
#                     </svg>
#                     <span id="notificaciones-counter"></span>
#                 </a>
#                 <!-- NOTIFICACION -->
#                 <div class="headerNexoNav__pop-up-notificacion" id="popup-alertas">
#                     <div class="flecha-notificacion"></div>
#
#                     <button id="cerrar-popup" class="cerrar-popup botonNotificaciones">&times;</button>
#                     <!-- <h3 class = "txt-notificacion">Notificaciones</h3> -->
#
#                     <div id="notificaciones-container"></div>
#                 </div>
#                 <button class="headerNexoNav__btn-favoritos">
#                     <i class="fa fa-heart"></i> <span class="txt-favoritos-count">Favoritos</span>&#160;(<span class="favoritos-count">0</span>&#160;)
#                 </button>
#                 <div class="favoritos-drawer">
#                     <div class="favoritos-drawer__content" style="position: relative;">
#                         <div class="favoritos-drawer__header">
#                             <button class="nolodejes-popup__close favoritos-drawer__close">
#                                 <svg xmlns="http://www.w3.org/2000/svg" width="20" height="20" fill="currentColor" viewBox="0 0 16 16">
#                                     <path d="M4.646 4.646a.5.5 0 0 1 .708 0L8 7.293l2.646-2.647a.5.5 0 0 1 .708.708L8.707 8l2.647 2.646a.5.5 0 0 1-.708.708L8 8.707l-2.646 2.647a.5.5 0 0 1-.708-.708L7.293 8 4.646 5.354a.5.5 0 0 1 0-.708z"/>
#                                 </svg>
#                             </button>
#                         </div>
#                         <div class="favoritos-drawer__body">
#                             <div class="favoritos-drawer__message">
#                                                                     <div class="favoritos-drawer__message-content">
#                                         <i class="fa fa-heart"></i>
#                                         <p class="title">Compara y ve tus proyectos favoritos</p>
#                                         <p class="description">Para visualizar tus proyectos favoritos ingresa tus siguientes datos.</p>
#                                     </div>
#                                     <!--Michael Vairo-->
#                                     <div class="drawer-formulario-favoritos">
#                                     <div class="modalLoginTabContent">
#                                         <div class="modal-body modalLoginTabContainer">
#                                             <!-- Nav tabs -->
#                                             <ul id="tabs_login" class="nav nav-tabs" role="tablist">
#                                                 <li role="presentation" class="headerTab headerTab--register"><a href="#tab-register-fav" aria-controls="tab-register" role="tab" data-toggle="tab">Regístrate</a></li>
#                                                 <li role="presentation" class="headerTab headerTab--login active"><a href="#tab-login-fav" aria-controls="tab-login" role="tab" data-toggle="tab">Iniciar Sesión</a></li>
#                                             </ul>
#                                             <!-- Tab panes -->
#                                             <div class="tab-content ">
#                                                 <div class="modalLoginTab__flashmessages">
#                                                                                                                                                                                                 </div>
#                                                 <div role="tabpanel" class="modalLoginTab__tab modalLoginTab__tab--register tab-pane" id="tab-register-fav" style="margin: 0px; padding-top: 0;">
#                                                     <div class="preloadHouse"><img src="https://nexoinmobiliario.pe/static/website/build/images/preload/preload.gif?v=202601120935" alt=""></div>
#                                                     <div id="message_register"></div>
#                                                     <div class="modalLoginTabContainer__form">
#                                                     <form id="formRegisterUser" action="">
#                                                                     <div class="form-group">
#                                                                         <input type="text" class="txt-nombres" id="nombresRegister" name="nombres" placeholder="Nombres">
#                                                                     </div>
#                                                                     <div class="form-group">
#                                                                         <input type="text" class="txt-apellidos" id="apellidosRegister" name="apellidos" placeholder="Apellidos">
#                                                                     </div>
#                                                                     <div class="form-group">
#                                                                         <input type="tel" class="txt-tel" id="celularRegister" name="celular" placeholder="Celular">
#                                                                     </div>
#                                                         <div class="form-group">
#                                                         <input type="email" class="form-control" id="emailRegister" name="emailRegister" autocomplete="false" placeholder="Correo electrónico">
#                                                         </div>
#                                                         <div class="form-group">
#                                                         <input type="password" class="form-control" id="passwordRegister" name="passwordRegister" autocomplete="false" placeholder="Contraseña">
#                                                         </div>

# %%
# 🔎 Parseo con BeautifulSoup: resumen rápido
soup = BeautifulSoup(html, "lxml")

title = soup.title.get_text(strip=True) if soup.title else None
h1 = soup.find("h1").get_text(strip=True) if soup.find("h1") else None
meta_desc = None
m = soup.find("meta", attrs={"name":"description"})
if m and m.get("content"):
    meta_desc = m["content"].strip()

print("Title:", title)
print("H1:", h1)
print("Meta description:", meta_desc)

# Conteos de elementos útiles
counts = {
    "a_links": len(soup.find_all("a")),
    "images": len(soup.find_all("img")),
    "scripts": len(soup.find_all("script")),
    "json_ld": len(soup.find_all("script", attrs={"type":"application/ld+json"})),
    "tables": len(soup.find_all("table")),
    "forms": len(soup.find_all("form")),
}
counts
# Out:
# Title: Edifica | 15 Proyectos en Venta en Nexo Inmobiliario
# H1: EDIFICA
# Meta description: Conoce los proyectos de Edifica. Precios desde S/. 419,136, con más de 15 en venta.
# {'a_links': 78,
#  'images': 24,
#  'scripts': 14,
#  'json_ld': 1,
#  'tables': 0,
#  'forms': 6}

# %%
# 🧠 Helpers: encontrar 'pistas' para identificar targets de scraping
def find_candidates_by_text(soup: BeautifulSoup, needle: str, max_matches=20):
    needle_low = needle.lower()
    matches = []
    for tag in soup.find_all(True):
        txt = tag.get_text(" ", strip=True)
        if txt and needle_low in txt.lower():
            matches.append(tag)
            if len(matches) >= max_matches:
                break
    return matches

def css_path(el):
    # path CSS aproximado para inspección (no perfecto, pero útil)
    path = []
    while el and getattr(el, "name", None) and el.name != "[document]":
        name = el.name
        _id = el.get("id")
        _class = el.get("class")
        if _id:
            seg = f"{name}#{_id}"
        elif _class:
            seg = f"{name}." + ".".join(_class[:3])
        else:
            seg = name
        path.append(seg)
        el = el.parent
    return " > ".join(reversed(path))

# EJEMPLO: busca un texto que veas en la página (cámbialo)
NEEDLE = "precio"  # <-- cambia según lo que buscas
cands = find_candidates_by_text(soup, NEEDLE)

print(f"Matches: {len(cands)}\n")
for i, tag in enumerate(cands[:10], 1):
    preview = tag.get_text(" ", strip=True)[:160]
    print(f"[{i}] {tag.name} | css≈ {css_path(tag)}")
    print("    text:", preview)
# Out:
# Matches: 0

# %%
# 🔗 Links y tablas (útil para descubrir endpoints o datos ya disponibles)
# Links
links = []
for a in soup.select("a[href]"):
    href = a.get("href")
    if not href:
        continue
    full = urljoin(resp["final_url"], href)
    links.append({
        "text": a.get_text(" ", strip=True)[:80],
        "href": href,
        "full_url": full
    })

df_links = pd.DataFrame(links).drop_duplicates(subset=["full_url"]).head(30)
df_links
# Out:
#                                      text  \
# 0
# 2                             Sello CODIP
# 3                           Inmobiliarias
# 4                             Nexo-Bancos
# 5                                    Blog
# 6
# 7                              Regístrate
# 8                          Iniciar Sesión
# 9                  Términos y Condiciones
# 10                 Política de Privacidad
# 16
# 22
# 23
# 24
# 25
# 26
# 27                  Departamentos en Lima
# 28            Departamentos en Miraflores
# 29             Departamentos en San Borja
# 30            Departamentos en San Miguel
# 31           Departamentos en Jesús María
# 32            Departamentos en San Isidro
# 33     Departamentos en Magdalena del Mar
# 34                 Departamentos en Lince
# 35            Departamentos en Los Olivos
# 36             Departamentos en La Molina
# 37  Departamentos en San Martín de Porres
# 38                   Departamentos en Ate
# 39          Departamentos en Pueblo Libre
# 40     Departamentos en Santiago de Surco
#
#                                                  href  \
# 0                        https://nexoinmobiliario.pe/
# 2             https://nexoinmobiliario.pe/sello-codip
# 3           https://nexoinmobiliario.pe/inmobiliarias
# 4                  https://nexoinmobiliario.pe/bancos
# 5                    https://blog.nexoinmobiliario.pe
# 6                                                   #
# 7                                   #tab-register-fav
# 8                                      #tab-login-fav
# 9   https://nexoinmobiliario.pe/terminos-y-condici...
# 10   https://nexoinmobiliario.pe/politicas-privacidad
# 16                           https://www.asei.com.pe/
# 22     https://www.facebook.com/nexoinmobiliarioperu/
# 23     https://www.instagram.com/nexoinmobiliario.pe/
# 24        https://www.tiktok.com/@nexoinmobiliario.pe
# 25  https://pe.linkedin.com/company/nexoinmobiliar...
# 26        https://www.youtube.com/@nexoinmobiliariotv
# 27                  /departamentos/departamentos-lima
# 28            /departamentos/departamentos-miraflores
# 29             /departamentos/departamentos-san-borja
# 30            /departamentos/departamentos-san-miguel
# 31           /departamentos/departamentos-jesus-maria
# 32            /departamentos/departamentos-san-isidro
# 33     /departamentos/departamentos-magdalena-del-mar
# 34                 /departamentos/departamentos-lince
# 35            /departamentos/departamentos-los-olivos
# 36             /departamentos/departamentos-la-molina
# 37  /departamentos/departamentos-san-martin-de-porres
# 38                   /departamentos/departamentos-ate
# 39          /departamentos/departamentos-pueblo-libre
# 40     /departamentos/departamentos-santiago-de-surco
#
#                                              full_url
# 0                        https://nexoinmobiliario.pe/
# 2             https://nexoinmobiliario.pe/sello-codip
# 3           https://nexoinmobiliario.pe/inmobiliarias
# 4                  https://nexoinmobiliario.pe/bancos
# 5                    https://blog.nexoinmobiliario.pe
# 6   https://nexoinmobiliario.pe/inmobiliarias/edifica
# 7   https://nexoinmobiliario.pe/inmobiliarias/edif...
# 8   https://nexoinmobiliario.pe/inmobiliarias/edif...
# 9   https://nexoinmobiliario.pe/terminos-y-condici...
# 10   https://nexoinmobiliario.pe/politicas-privacidad
# 16                           https://www.asei.com.pe/
# 22     https://www.facebook.com/nexoinmobiliarioperu/
# 23     https://www.instagram.com/nexoinmobiliario.pe/
# 24        https://www.tiktok.com/@nexoinmobiliario.pe
# 25  https://pe.linkedin.com/company/nexoinmobiliar...
# 26        https://www.youtube.com/@nexoinmobiliariotv
# 27  https://nexoinmobiliario.pe/departamentos/depa...
# 28  https://nexoinmobiliario.pe/departamentos/depa...
# 29  https://nexoinmobiliario.pe/departamentos/depa...
# 30  https://nexoinmobiliario.pe/departamentos/depa...
# 31  https://nexoinmobiliario.pe/departamentos/depa...
# 32  https://nexoinmobiliario.pe/departamentos/depa...
# 33  https://nexoinmobiliario.pe/departamentos/depa...
# 34  https://nexoinmobiliario.pe/departamentos/depa...
# 35  https://nexoinmobiliario.pe/departamentos/depa...
# 36  https://nexoinmobiliario.pe/departamentos/depa...
# 37  https://nexoinmobiliario.pe/departamentos/depa...
# 38  https://nexoinmobiliario.pe/departamentos/depa...
# 39  https://nexoinmobiliario.pe/departamentos/depa...
# 40  https://nexoinmobiliario.pe/departamentos/depa...

# %%
# 🧾 Extraer JSON-LD (a veces trae precios, direcciones, productos, etc.)
jsonlds = []
for s in soup.find_all("script", attrs={"type":"application/ld+json"}):
    raw = s.get_text(strip=True)
    if not raw:
        continue
    try:
        obj = json.loads(raw)
        jsonlds.append(obj)
    except Exception:
        # a veces viene malformado
        jsonlds.append({"_raw": raw[:2000]})

len(jsonlds), (jsonlds[0] if jsonlds else None)
# Out:
# (1,
#  {'@context': 'https://schema.org',
#   '@type': 'Organization',
#   'name': 'EDIFICA',
#   'description': 'Somos una empresa inmobiliaria que nació en el año 2005. Hoy ya son más de 3000 familias que han confiado en nosotros y disfrutan de una nueva vida en cada uno de nuestros proyectos entregados.',
#   'url': 'https://nexoinmobiliario.pe/inmobiliarias/edifica',
#   'logo': 'https://e.nexoinmobiliario.pe/customers/edifica/logo-47-20250912111830.jpg',
#   'location': {'@type': 'Place',
#    'address': {'@type': 'PostalAddress',
#     'addressLocality': 'Lima',
#     'addressCountry': 'PE'}},
#   'department': {'@type': 'ItemList',
#    'name': 'Proyectos de EDIFICA',
#    'numberOfItems': 15,
#    'itemListElement': [{'@type': 'Product',
#      'name': 'Urban Heights',
#      'category': 'Proyecto inmobiliario',
#      'url': 'https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3215-urban-heights-miraflores-lima-lima-edifica',
#      'offers': {'@type': 'Offer',
#       'priceCurrency': 'PEN',
#       'price': 419136.18,
#       'availability': 'https://schema.org/InStock'},
#      'areaServed': {'@type': 'Place', 'name': 'Miraflores'},
#      'additionalProperty': [{'@type': 'PropertyValue',
#        'name': 'Área',
#        'value': '40.00 - 149.13 m2'},
#       {'@type': 'PropertyValue',
#        'name': 'Dormitorios',
#        'value': '1 - 2 dormitorios'}]},
#     {'@type': 'Product',
#      'name': 'Affinity',
#      'category': 'Proyecto inmobiliario',
#      'url': 'https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3524-affinity-miraflores-lima-lima-edifica',
#      'offers': {'@type': 'Offer',
#       'priceCurrency': 'PEN',
#       'price': 424280.03,
#       'availability': 'https://schema.org/InStock'},
#      'areaServed': {'@type': 'Place', 'name': 'Miraflores'},
#      'additionalProperty': [{'@type': 'PropertyValue',
#        'name': 'Área',
#        'value': '40.01 - 62.18 m2'},
#       {'@type': 'PropertyValue',
#        'name': 'Dormitorios',
#        'value': '1 - 2 dormitorios'}]},
#     {'@type': 'Product',
#      'name': 'Element',
#      'category': 'Proyecto inmobiliario',
#      'url': 'https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3476-element-surquillo-lima-lima-edifica',
#      'offers': {'@type': 'Offer',
#       'priceCurrency': 'PEN',
#       'price': 278168.05,
#       'availability': 'https://schema.org/InStock'},
#      'areaServed': {'@type': 'Place', 'name': 'Surquillo'},
#      'additionalProperty': [{'@type': 'PropertyValue',
#        'name': 'Área',
#        'value': '28.91 - 60.13 m2'},
#       {'@type': 'PropertyValue',
#        'name': 'Dormitorios',
#        'value': '1 - 3 dormitorios'}]},
#     {'@type': 'Product',
#      'name': 'Condominio HOME - II Etapa',
#      'category': 'Proyecto inmobiliario',
#      'url': 'https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2353-condominio-home-ii-etapa-cayma-arequipa-arequipa-edifica',
#      'offers': {'@type': 'Offer',
#       'priceCurrency': 'PEN',
#       'price': 464397.91,
#       'availability': 'https://schema.org/InStock'},
#      'areaServed': {'@type': 'Place', 'name': 'Cayma'},
#      'additionalProperty': [{'@type': 'PropertyValue',
#        'name': 'Área',
#        'value': '61.16 - 108.87 m2'},
#       {'@type': 'PropertyValue',
#        'name': 'Dormitorios',
#        'value': '2 - 3 dormitorios'}]},
#     {'@type': 'Product',
#      'name': 'Legacy',
#      'category': 'Proyecto inmobiliario',
#      'url': 'https://nexoinmobiliario.pe/proyecto/venta-de-departamento-4069-legacy-miraflores-lima-lima-edifica',
#      'offers': {'@type': 'Offer',
#       'priceCurrency': 'PEN',
#       'price': 604066.91,
#       'availability': 'https://schema.org/InStock'},
#      'areaServed': {'@type': 'Place', 'name': 'Miraflores'},
#      'additionalProperty': [{'@type': 'PropertyValue',
#        'name': 'Área',
#        'value': '60.05 - 75.93 m2'},
#       {'@type': 'PropertyValue',
#        'name': 'Dormitorios',
#        'value': '2 - 3 dormitorios'}]},
#     {'@type': 'Product',
#      'name': 'Ascent',
#      'category': 'Proyecto inmobiliario',
#      'url': 'https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3852-ascent-san-isidro-lima-lima-edifica',
#      'offers': {'@type': 'Offer',
#       'priceCurrency': 'PEN',
#       'price': 673888.51,
#       'availability': 'https://schema.org/InStock'},
#      'areaServed': {'@type': 'Place', 'name': 'San Isidro'},
#      'additionalProperty': [{'@type': 'PropertyValue',
#        'name': 'Área',
#        'value': '60.00 - 80.02 m2'},
#       {'@type': 'PropertyValue',
#        'name': 'Dormitorios',
#        'value': '1 - 3 dormitorios'}]},
#     {'@type': 'Product',
#      'name': 'The Edge',
#      'category': 'Proyecto inmobiliario',
#      'url': 'https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3350-the-edge-miraflores-lima-lima-edifica',
#      'offers': {'@type': 'Offer',
#       'priceCurrency': 'PEN',
#       'price': 983656.6,
#       'availability': 'https://schema.org/InStock'},
#      'areaServed': {'@type': 'Place', 'name': 'Miraflores'},
#      'additionalProperty': [{'@type': 'PropertyValue',
#        'name': 'Área',
#        'value': '66.74 - 120.47 m2'},
#       {'@type': 'PropertyValue',
#        'name': 'Dormitorios',
#        'value': '2 - 3 dormitorios'}]},
#     {'@type': 'Product',
#      'name': 'Grau 10',
#      'category': 'Proyecto inmobiliario',
#      'url': 'https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3809-grau-10-barranco-lima-lima-edifica',
#      'offers': {'@type': 'Offer',
#       'priceCurrency': 'PEN',
#       'price': 397088.01,
#       'availability': 'https://schema.org/InStock'},
#      'areaServed': {'@type': 'Place', 'name': 'Barranco'},
#      'additionalProperty': [{'@type': 'PropertyValue',
#        'name': 'Área',
#        'value': '40.00 - 83.00 m2'},
#       {'@type': 'PropertyValue',
#        'name': 'Dormitorios',
#        'value': '1 - 2 dormitorios'}]},
#     {'@type': 'Product',
#      'name': 'Bloom',
#      'category': 'Proyecto inmobiliario',
#      'url': 'https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3866-bloom-lince-lima-lima-edifica',
#      'offers': {'@type': 'Offer',
#       'priceCurrency': 'PEN',
#       'price': 372117.46,
#       'availability': 'https://schema.org/InStock'},
#      'areaServed': {'@type': 'Place', 'name': 'Lince'},
#      'additionalProperty': [{'@type': 'PropertyValue',
#        'name': 'Área',
#        'value': '36.50 - 69.92 m2'},
#       {'@type': 'PropertyValue',
#        'name': 'Dormitorios',
#        'value': '1 - 3 dormitorios'}]},
#     {'@type': 'Product',
#      'name': 'Upper 28',
#      'category': 'Proyecto inmobiliario',
#      'url': 'https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3051-upper-28-miraflores-lima-lima-edifica',
#      'offers': {'@type': 'Offer',
#       'priceCurrency': 'PEN',
#       'price': 776427.93,
#       'availability': 'https://schema.org/InStock'},
#      'areaServed': {'@type': 'Place', 'name': 'Miraflores'},
#      'additionalProperty': [{'@type': 'PropertyValue',
#        'name': 'Área',
#        'value': '75.27 - 128.30 m2'},
#       {'@type': 'PropertyValue',
#        'name': 'Dormitorios',
#        'value': '2 - 3 dormitorios'}]},
#     {'@type': 'Product',
#      'name': 'The Muse',
#      'category': 'Proyecto inmobiliario',
#      'url': 'https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3946-the-muse-barranco-lima-lima-edifica',
#      'offers': {'@type': 'Offer',
#       'priceCurrency': 'PEN',
#       'price': 389130.34,
#       'availability': 'https://schema.org/InStock'},
#      'areaServed': {'@type': 'Place', 'name': 'Barranco'},
#      'additionalProperty': [{'@type': 'PropertyValue',
#        'name': 'Área',
#        'value': '40.00 - 60.30 m2'},
#       {'@type': 'PropertyValue',
#        'name': 'Dormitorios',
#        'value': '1 - 2 dormitorios'}]},
#     {'@type': 'Product',
#      'name': 'Monument',
#      'category': 'Proyecto inmobiliario',
#      'url': 'https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3593-monument-miraflores-lima-lima-edifica',
#      'offers': {'@type': 'Offer',
#       'priceCurrency': 'PEN',
#       'price': 654774.19,
#       'availability': 'https://schema.org/InStock'},
#      'areaServed': {'@type': 'Place', 'name': 'Miraflores'},
#      'additionalProperty': [{'@type': 'PropertyValue',
#        'name': 'Área',
#        'value': '68.00 - 85.99 m2'},
#       {'@type': 'PropertyValue',
#        'name': 'Dormitorios',
#        'value': '1 - 2 dormitorios'}]},
#     {'@type': 'Product',
#      'name': 'ACACIAS',
#      'category': 'Proyecto inmobiliario',
#      'url': 'https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3642-acacias-miraflores-lima-lima-edifica',
#      'offers': {'@type': 'Offer',
#       'priceCurrency': 'PEN',
#       'price': 618043.27,
#       'availability': 'https://schema.org/InStock'},
#      'areaServed': {'@type': 'Place', 'name': 'Miraflores'},
#      'additionalProperty': [{'@type': 'PropertyValue',
#        'name': 'Área',
#        'value': '63.34 - 194.21 m2'},
#       {'@type': 'PropertyValue',
#        'name': 'Dormitorios',
#        'value': '1 - 3 dormitorios'}]},
#     {'@type': 'Product',
#      'name': 'The Lead',
#      'category': 'Proyecto inmobiliario',
#      'url': 'https://nexoinmobiliario.pe/proyecto/venta-de-departamento-2933-the-lead-san-isidro-lima-lima-edifica',
#      'offers': {'@type': 'Offer',
#       'priceCurrency': 'PEN',
#       'price': 709698.56,
#       'availability': 'https://schema.org/InStock'},
#      'areaServed': {'@type': 'Place', 'name': 'San Isidro'},
#      'additionalProperty': [{'@type': 'PropertyValue',
#        'name': 'Área',
#        'value': '64.70 - 138.15 m2'},
#       {'@type': 'PropertyValue',
#        'name': 'Dormitorios',
#        'value': '2 - 2 dormitorios'}]},
#     {'@type': 'Product',
#      'name': 'Francisco Del Castillo 252',
#      'category': 'Proyecto inmobiliario',
#      'url': 'https://nexoinmobiliario.pe/proyecto/venta-de-departamento-3487-francisco-del-castillo-252-miraflores-lima-lima-edifica',
#      'offers': {'@type': 'Offer',
#       'priceCurrency': 'PEN',
#       'price': 722790.61,
#       'availability': 'https://schema.org/InStock'},
#      'areaServed': {'@type': 'Place', 'name': 'Miraflores'},
#      'additionalProperty': [{'@type': 'PropertyValue',
#        'name': 'Área',
#        'value': '80.30 - 175.77 m2'},
#       {'@type': 'PropertyValue',
#        'name': 'Dormitorios',
#        'value': '2 - 3 dormitorios'}]}]}})

# %%
# ⚠️ Señales de sitio dinámico (JS)
signals = {
    "has_react": bool(re.search(r"react|__NEXT_DATA__", html, re.I)),
    "has_nextjs_data": "__NEXT_DATA__" in html,
    "has_vue": bool(re.search(r"__NUXT__|vue", html, re.I)),
    "has_angular": bool(re.search(r"angular|ng-version", html, re.I)),
    "many_scripts": counts["scripts"] > 25,
    "few_text": len(soup.get_text(" ", strip=True)) < 800,
}
signals
# Out:
# {'has_react': False,
#  'has_nextjs_data': False,
#  'has_vue': False,
#  'has_angular': False,
#  'many_scripts': False,
#  'few_text': False}

# %%
# 💾 Guardar snapshot del HTML para inspección offline
from pathlib import Path

out_dir = Path("dom_snapshots")
out_dir.mkdir(exist_ok=True)

safe_name = re.sub(r"[^a-zA-Z0-9_-]+", "_", urlparse(resp["final_url"]).netloc)
ts = int(time.time())
html_path = out_dir / f"{safe_name}_{ts}.html"
html_path.write_text(html, encoding="utf-8")

print("Guardado:", html_path.resolve())
# Out:
# Guardado: C:\Users\User\Documents\support\notes\proyecto_ideal\property_scrappers_v2\notebooks\dom_snapshots\nexoinmobiliario_pe_1768742729.html

# %% [markdown]
# ## 🧯 Fallback: Playwright (renderizado)
#
# Si el HTML inicial **no trae datos** (porque se llenan con JS), usa Playwright para:
#
# - Renderizar la página como navegador
# - Esperar a que aparezcan elementos
# - Capturar el DOM final y/o interceptar XHR (paso siguiente)
#
# > Playwright puede requerir instalación de navegador.

# %%
# 🧯 Playwright fallback (opcional)
# 1) Instala Playwright:
# !pip -q install playwright
# 2) Instala los navegadores (una vez):
# !playwright install chromium

# Luego ejecuta este bloque.
from pathlib import Path
import asyncio

async def fetch_rendered_dom(url: str, wait_ms: int = 2500, selector_wait: str | None = None):
    from playwright.async_api import async_playwright

    async with async_playwright() as p:
        browser = await p.chromium.launch(headless=True)
        page = await browser.new_page()
        await page.goto(url, wait_until="domcontentloaded", timeout=60_000)

        # Espera extra para JS
        if selector_wait:
            try:
                await page.wait_for_selector(selector_wait, timeout=20_000)
            except Exception:
                pass

        await page.wait_for_timeout(wait_ms)
        content = await page.content()
        final_url = page.url

        # Guardar screenshot + html
        out_dir = Path("dom_snapshots")
        out_dir.mkdir(exist_ok=True)
        safe = re.sub(r"[^a-zA-Z0-9_-]+", "_", urlparse(final_url).netloc)
        ts = int(time.time())
        html_path = out_dir / f"{safe}_{ts}_rendered.html"
        png_path = out_dir / f"{safe}_{ts}_rendered.png"
        html_path.write_text(content, encoding="utf-8")
        await page.screenshot(path=str(png_path), full_page=True)

        await browser.close()
        return final_url, content, html_path, png_path

# Configura si quieres esperar por un elemento específico (CSS selector)
WAIT_SELECTOR = None  # e.g. ".card-price"  o  "text=Precio"
WAIT_MS = 3000

# Ejecutar
final_url_pw, html_pw, html_path_pw, png_path_pw = await fetch_rendered_dom(URL, wait_ms=WAIT_MS, selector_wait=WAIT_SELECTOR)

print("Final URL (Playwright):", final_url_pw)
print("HTML rendered length:", len(html_pw))
print("Guardado HTML:", html_path_pw.resolve())
print("Guardado PNG:", png_path_pw.resolve())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 48
#      45 WAIT_MS = 3000
#      47 # Ejecutar
# ---> 48 final_url_pw, html_pw, html_path_pw, png_path_pw = await fetch_rendered_dom(URL, wait_ms=WAIT_MS, selector_wait=WAIT_SELECTOR)
#      50 print("Final URL (Playwright):", final_url_pw)
#      51 print("HTML rendered length:", len(html_pw))
#
# Cell In[12], line 12, in fetch_rendered_dom(url, wait_ms, selector_wait)
#      11 async def fetch_rendered_dom(url: str, wait_ms: int = 2500, selector_wait: str | None = None):
# ---> 12     from playwright.async_api import async_playwright
#      14     async with async_playwright() as p:
#      15         browser = await p.chromium.launch(headless=True)
#
# ModuleNotFoundError: No module named 'playwright'

# %%
# 🔁 Comparar: Requests vs Renderizado (solo si corriste Playwright)
# Si no lo corriste, ignora este bloque.
try:
    ratio = len(html_pw) / max(1, len(html))
    print("len(rendered)/len(requests) =", round(ratio, 2))
    print("\nPreview rendered HEAD:\n")
    print(html_pw[:MAX_HTML_CHARS_PREVIEW])
except NameError:
    print("Playwright no fue ejecutado aún.")

# %% [markdown]
# ## ✅ Qué identificar para scrapear (checklist rápido)
#
# 1) **Entidad objetivo**: ¿Qué quieres extraer? (precio, m², tipología, ubicación, disponibilidad, etc.)
# 2) **Selector estable**: usa `id`, clases semánticas, o atributos (`data-*`) antes que rutas frágiles.
# 3) **Modelo de datos**: define tu schema desde ya (campos fijos).
# 4) **Fallback**:
#    - Si Requests no trae el dato → Playwright renderiza.
#    - Si el dato viene de XHR/JSON → conviene interceptar endpoint (más limpio que parsear HTML).
# 5) **Anti-duplicados**: define llave única (por ejemplo `proyecto + tipología + precio + fecha_captura`).
#
# Si quieres, pega:
# - la URL real
# - qué campos necesitas
# y te armo los selectores + extracción + normalización + dedupe.
